# %%
import numpy as np

# %%
arr = np.array([3, 5, 2, 33])

# %%
np.mean(arr)
# Out:
# np.float64(10.75)

# %%
np.min(arr)
# Out:
# np.int64(2)

# %%
np.max(arr)
# Out:
# np.int64(33)

# %%
np.std(arr)    #Standard diviation
# Out:
# np.float64(12.891373084353738)

# %%
np.var(arr)    #Variance
# Out:
# np.float64(166.1875)

# %%
np.sum(arr)    # sum of all
# Out:
# np.int64(43)

# %%
np.prod(arr)     #product of all elements / multiply all
# Out:
# np.int64(990)

# %%
np.median(arr)    #median
# Out:
# np.float64(4.0)

# %%
np.percentile(arr, 50)   #
# Out:
# np.float64(4.0)

# %%
np.argmin(arr)     #retuen index of minimun
# Out:
# np.int64(2)

# %%
np.argmax(arr)    # return index of max
# Out:
# np.int64(3)

# %%
np.corrcoef(arr)   # corelation - coeffection
# Out:
# np.float64(1.0)

# %%
arr = np.array([3, 5, 2, 33, 2, 1, 10, 1])

# %%
np.unique(arr)    #  ***Highly used***   Finds unique elements
# Out:
# array([ 1,  2,  3,  5, 10, 33])

# %%
np.cumsum(arr)    #Cumalative sum
# Out:
# array([ 3,  8, 10, 43, 45, 46, 56, 57])

# %%
np.diff(arr)    # n'th  difference
# Out:
# array([  2,  -3,  31, -31,  -1,   9,  -9])

# %%
np.linspace(0, 10, 5)    #evenly space numbers
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.log(arr)    # natural algorithm
# Out:
# array([1.09861229, 1.60943791, 0.69314718, 3.49650756, 0.69314718,
#        0.        , 2.30258509, 0.        ])

# %%
np.exp(arr)   # expodential
# Out:
# array([2.00855369e+01, 1.48413159e+02, 7.38905610e+00, 2.14643580e+14,
#        7.38905610e+00, 2.71828183e+00, 2.20264658e+04, 2.71828183e+00])
