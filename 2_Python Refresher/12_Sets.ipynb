# %% [markdown]
# ### Sets and its methods

# %%
a ={}

# %%
type(a)
# Out:
# dict

# %%
b = set()

# %%
type(b)
# Out:
# set

# %%
s = {4, 3, 6, 2, 66, 4}

# %%
s
# Out:
# {2, 3, 4, 6, 66}

# %%
s.add(34)

# %%
s
# Out:
# {2, 3, 4, 6, 34, 66}

# %%
s.update([4, 64, 233])

# %%
s
# Out:
# {2, 3, 4, 6, 34, 64, 66, 233}

# %%
s.add(12)

# %%
s
# Out:
# {2, 3, 4, 6, 12, 34, 64, 66, 233}

# %%
s.remove(12)

# %%
s
# Out:
# {2, 3, 4, 6, 34, 64, 66, 233}

# %%
s.update([88, 99])

# %%
s
# Out:
# {2, 3, 4, 6, 34, 64, 66, 88, 99, 233}

# %%
s.discard(88)

# %%
s
# Out:
# {2, 3, 4, 6, 34, 64, 66, 99, 233}

# %%
s.discard(99)

# %%
s
# Out:
# {2, 3, 4, 6, 34, 64, 66, 233}

# %%
s.pop()
# Out:
# 64

# %%
s
# Out:
# {2, 3, 4, 6, 34, 66, 233}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s.copy
# Out:
# <function set.copy()>

# %%
s
# Out:
# set()

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
set1.difference(set2)
# Out:
# {1, 2}

# %%
set1.symmetric_difference(set2)
# Out:
# {1, 2, 5, 6}

# %%
set1.issubset(set2)
# Out:
# False

# %%
 sub = {1, 3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
