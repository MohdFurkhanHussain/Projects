# %% [markdown]
# ## Operator precedence in python
# ### BODMAS
# ###### B = Brackets (){} []
# ###### O = Order or Power  2**5, 3**7. root2
# ###### D = Division (/)
# ###### M = Multiplication *
# ###### A = Addision +
# ###### S = Subraction -

# %% [markdown]
# ### Python follows PEDMAS
# Paranthases (), exponents **. Multiplaction *, Division /, Floor Division //, Modulus %, Addaction +, Subraction -.

# %%
#Example
result = 10+2*3 # first it will multiply and then add

# %%
result
# Out:
# 16

# %%
54*3/23+4-2**5
# Out:
# -20.956521739130434

# %%
54*3/23+4-32
# Out:
# -20.956521739130434

# %%
162/23+4-32
# Out:
# -20.956521739130434

# %%
print(2**3**2)  #exponents ** are done right to left and all others are done left to right
# Out:
# 512

# %%
print(2**(3**2))
# Out:
# 512
