# %%
name = "Harry"

# %%
name
# Out:
# 'Harry'

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name.endswith("ry")
# Out:
# True

# %%
name.endswith("jerry")
# Out:
# False

# %%
name.count("a")
# Out:
# 1

# %%
name.count("r")
# Out:
# 2

# %% [markdown]
# time series tools .
# arema and profit and lstm for forcasting

# %%
s = "codewithharry"
print(len(s))  #Output 13
# Out:
# 13

# %%
s[0:5]
# Out:
# 'codew'

# %%
s[1:-1]
# Out:
# 'odewithharr'

# %%
s[1:12]
# Out:
# 'odewithharr'

# %%
s[-12:-1]
# Out:
# 'odewithharr'
