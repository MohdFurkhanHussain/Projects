# %% [markdown]
# ### File Handleing

# %%
f = open("Text.txt", "r")

# %%
f.read()
# Out:
# 'Furkhan\nHas became one of the greathest of all time\nAlhmd'

# %%
f = open("Text.txt", "r")

# %%
f.read()
# Out:
# 'Furkhan\nHas became one of the greatest of all time\nAlhmdulliah\n'

# %%
f.close()

# %%
s = "This is Great"

# %%
f = open("Hussain.txt", "w")

# %%
f.write(s)
# Out:
# 13

# %%
f.close()

# %%
f = open("Hussain.txt", "a")
f.write("\nThis is an additional line.")
# Out:
# 28

# %%
f.close()

# %%
with open("Hussain.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# This is Great
# This is an additional line.
