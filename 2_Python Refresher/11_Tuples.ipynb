# %% [markdown]
# ### Tuple

# %%
e = ()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
t = (5, 64, 23, 23)

# %%
t
# Out:
# (5, 64, 23, 23)

# %%
len(t)
# Out:
# 4

# %%
t[1]
# Out:
# 64

# %%
t[0]
# Out:
# 5

# %%
# t[1] = 34 ,  it will show error cause tuple is immutable

# %%
person = ("Furkhan", 27, "Enturepuner Billioner")
name, age, profession = person

# %%
name
# Out:
# 'Furkhan'

# %%
age
# Out:
# 27

# %%
profession
# Out:
# 'Enturepuner Billioner'
