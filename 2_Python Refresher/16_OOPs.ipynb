# %% [markdown]
# ### Object Oriented Programming.

# %% [raw]
# Class             class car:
# object            car1 = car()
# Encapsulation     self.__balance
# Inheritance       class Dog(Animal)
# polymorphisom     def fly(self)
# Abstraction       @abstractmethod
# Magic Methods     def __len__(self)
# Class Methods     @classmethod
# Static Methods    @staticmethod

# %%
class Employee:
    company = "HP"
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def printdetails(self):
        print(f"The company of {self.name} is {self.company} with salary ${self.salary}")

e = Employee("Harry", 47000)
e.printdetails()
# Out:
# The company of Harry is HP with salary $47000

# %%
class Employee:
    company = "HP"
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def printdetails(self):     # we have to take self by default
        print(f"The company of {self.name} is {self.company} with salary ${self.salary}")

    @staticmethod    #its used for not taking self
    def printTime():
        print(f"The time is now")

    @classmethod
    def printClassDetails(cls):
        print(f"the company is {cls.company}")

e = Employee("Harry", 47000)
e.printdetails()    
e.printTime()
e.printClassDetails()
# Out:
# The company of Harry is HP with salary $47000
# The time is now
# the company is HP
