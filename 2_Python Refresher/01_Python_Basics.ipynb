# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "harry"

# %%
print("hello world") # this will show hello world
# Out:
# hello world

# %%
# this is a comment

# %%
print(type (a))
# Out:
# <class 'int'>

# %%
print(type (name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a = "4566"

# %%
b = "5677"

# %%
print(a+b)
# Out:
# 45665677

# %%
int(a) + int(b) # Typecasting
# Out:
# 10243
