# %% [markdown]
# ### List and its methods

# %%
l = [3, 5, 23, 3]

# %%
l[0] = 4

# %%
l
# Out:
# [4, 5, 23, 3]

# %%
l.append(9)

# %%
l
# Out:
# [4, 5, 23, 3, 9]

# %%
l2 = [5, 7]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 5, 23, 3, 9, 5, 7]

# %%
l.insert(1, 200)

# %%
l
# Out:
# [4, 200, 5, 23, 3, 9, 5, 7]

# %%
number = l.pop(4)

# %%
number
# Out:
# 3

# %%
l
# Out:
# [4, 200, 5, 23, 9, 5, 7]

# %%
l.index(4)
# Out:
# 0

# %%
l.index(23)
# Out:
# 3

# %%
l.append(4)

# %%
l
# Out:
# [4, 200, 5, 23, 9, 5, 7, 4]

# %%
l.count(4)
# Out:
# 2

# %%
l.sort()

# %%
l
# Out:
# [4, 4, 5, 5, 7, 9, 23, 200]

# %%
sorted(l)
# Out:
# [4, 4, 5, 5, 7, 9, 23, 200]

# %%
newl = [2, 6,1, 21, 6]

# %%
sorted(newl)
# Out:
# [1, 2, 6, 6, 21]

# %%
newl
# Out:
# [2, 6, 1, 21, 6]

# %%
y = [1, 2, True, False,[4, 7]]

# %%
y
# Out:
# [1, 2, True, False, [4, 7]]

# %%
y[4]
# Out:
# [4, 7]

# %%
y[4][1]
# Out:
# 7

# %%
lst1 = [4, 32, 12]

# %%
lst2 = [3, 1, 8]

# %%
lst3 = lst1 + lst2

# %%
lst3
# Out:
# [4, 32, 12, 3, 1, 8]

# %%
3 in lst2
# Out:
# True

# %%
33 in lst2
# Out:
# False

# %%
if 3 in lst2:
    print("Yes!")
# Out:
# Yes!

# %%
s = "Jack-Jill-kriti-Jawed-Akther-Salman"

# %%
s.split("-")
# Out:
# ['Jack', 'Jill', 'kriti', 'Jawed', 'Akther', 'Salman']
