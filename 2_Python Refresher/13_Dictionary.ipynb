# %% [markdown]
# ### Dictionary

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
student = {
    "name" : "Furkhan",
    "age" : 27,
    "Grade" : "A+",
}

# %%
student["name"]
# Out:
# 'Furkhan'

# %%
# student("name4") it will show error

# %%
r = student.get("name4")

# %%
r

# %%
print(r)
# Out:
# None

# %%
student = {
    "name" : "Furkhan",
    "age" : 27,
    "Grade" : "A+",
}

# %%
student["age"]
# Out:
# 27

# %%
student["age"] = 27.11

# %%
student["age"]
# Out:
# 27.11

# %%
students.keys()
# Out:
# dict_keys(['name', 'age', 'Grade'])

# %%
student.values()
# Out:
# dict_values(['Furkhan', 27.11, 'A+'])

# %%
student.items()
# Out:
# dict_items([('name', 'Furkhan'), ('age', 27.11), ('Grade', 'A+')])

# %%
student.update({"name" : "Mohd Furkhan Hussain"})

# %%
student
# Out:
# {'name': 'Mohd Furkhan Hussain', 'age': 27.11, 'Grade': 'A+'}

# %%
student.update({"language": "English, Hindi, Urdu"})

# %%
student
# Out:
# {'name': 'Mohd Furkhan Hussain',
#  'age': 27.11,
#  'Grade': 'A+',
#  'language': 'English, Hindi, Urdu'}

# %%
student.get("name")
# Out:
# 'Mohd Furkhan Hussain'

# %%
student.pop("language")
# Out:
# 'English, Hindi, Urdu'

# %%
student
# Out:
# {'name': 'Mohd Furkhan Hussain', 'age': 27.11, 'Grade': 'A+'}

# %%
student.popitem()
# Out:
# ('Grade', 'A+')

# %%
student
# Out:
# {'name': 'Mohd Furkhan Hussain', 'age': 27.11}

# %%
student
# Out:
# {'name': 'Mohd Furkhan Hussain',
#  'age': 27,
#  'Grade': 'A+',
#  'language': 'English, Hindi, Urdu'}

# %%
student.setdefault("age")
# Out:
# 27

# %%
student
# Out:
# {'name': 'Mohd Furkhan Hussain',
#  'age': 27,
#  'Grade': 'A+',
#  'language': 'English, Hindi, Urdu'}

# %%
student.copy()
# Out:
# {'name': 'Mohd Furkhan Hussain',
#  'age': 27,
#  'Grade': 'A+',
#  'language': 'English, Hindi, Urdu'}

# %%
student.clear()

# %%
student
# Out:
# {}
