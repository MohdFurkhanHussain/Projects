# %% [markdown]
# ## Arithmetic Operators

# %%
a = 11
b = 5

# %%
a+b
# Out:
# 16

# %%
a-b
# Out:
# 6

# %%
a*b
# Out:
# 55

# %%
a/b
# Out:
# 2.2

# %%
a//b
# Out:
# 2

# %%
a%b
# Out:
# 1

# %%
2**2
# Out:
# 4

# %%
2**5
# Out:
# 32

# %%
a**b
# Out:
# 161051

# %% [markdown]
# ## Comparision Operators
# boolians

# %%
a = 45
b = 4

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
c = 3

# %%
a == c # is a equal to c?
# Out:
# False

# %%
a != c
# Out:
# True

# %%
a = 5
b = 5

# %%
a == b
# Out:
# True

# %%
b == a
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
b>=a
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
b<=a
# Out:
# True

# %% [markdown]
# ## Logical Operators
# used to combine conditional statements

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1
# Out:
# True

# %%
b2
# Out:
# False

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# ## Bitwise operators

# %%
a = 5
b = 3

# %%
a & b
# Out:
# 1

# %%
a or b
# Out:
# 5

# %% [markdown]
# ## Assignment operators

# %%
a = 45

# %%
a -=4

# %%
a
# Out:
# 41

# %%
a += 4

# %%
a
# Out:
# 45

# %%
a*=4

# %%
a
# Out:
# 180

# %%
a/=4

# %%
a
# Out:
# 0.0

# %%
a%=4

# %%
a
# Out:
# 1.0

# %%
a//=4

# %%
a
# Out:
# 11

# %%
a**=4

# %%
a
# Out:
# 4100625

# %%
a**4
# Out:
# 4100625

# %% [markdown]
# ## Membership andIdenty operators

# %%
lst = [1,2,3]
x = 2

# %%
x in lst
# Out:
# True

# %%
x not in lst
# Out:
# False

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True
