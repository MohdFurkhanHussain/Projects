# %%
s = "Harry"

# %%
s
# Out:
# 'Harry'

# %%
s.upper()
# Out:
# 'HARRY'

# %%
s
# Out:
# 'Harry'

# %%
s[0]
# Out:
# 'H'

# %%
# s[0] = 'A'      - Strings are immutable

# %%
name = "Adam"
age = 26
print("my name is {}, and I am {} year's old".format(name, age))
# Out:
# my name is Adam, and I am 26 year's old

# %%
name = "boss Furkhan"
occupation = "Multi Billioner"
print("He is {} and he is a {}".format(name, occupation))
# Out:
# He is boss Furkhan and he is a Multi Billioner

# %%
print(f"He is {name} and he is a {occupation}")
# Out:
# He is boss Furkhan and he is a Multi Billioner

# %% [markdown]
# #### Expression inside f-Strings

# %%
a = 5 
b =10
print(f"sum of {a} and {b} is {a + b}")
# Out:
# sum of 5 and 10 is 15

# %% [markdown]
# #### Formatting Strings

# %%
pi = 3.14159
print(f"pi founded to two decimal places: {pi:.2f}")
# Out:
# pi founded to two decimal places: 3.14

# %% [markdown]
# #### Padding and Alignment

# %%
print(f"{'python':<10}")    # Left-align
print(f"{'python':>10}")    # Right-align
print(f"{'python':^10}")    # Center-align
# Out:
# python
#     python
#   python

# %% [markdown]
# #### practice

# %%
#rows = 5
#for i in range(1, rows +1):
    #print(" " * (rows -i) + "*" * (2 * i-1))
