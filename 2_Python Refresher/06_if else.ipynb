# %% [markdown]
# ## Conditional statement in python
# #### if, elif, else.

# %%
a=4

# %%
if(a>53):
    print("Greater")
else:
    print("Smaller")
# Out:
# Smaller

# %%
a = 400

# %%
if(a>53):
    print("Greater")
else:
    print("Smaller")
# Out:
# Greater

# %%
if a>53:
    print("Greater")
else:
    print("Smaller")
# Out:
# Smaller

# %% [markdown]
# ### if else ladder

# %%
a = 41
if a>50 :
    print("Greater than 50")
elif(a>40):
    print("Greater than 40")
elif(a>30):
    print("Greater than 30")
else:
    print("Done")
# Out:
# Greater than 40

# %%
a = 29
if a>50 :
    print("Greater than 50")
elif(a>40):
    print("Greater than 40")
elif(a>30):
    print("Greater than 30")
else:
    print("Done")
# Out:
# Done

# %%
a = 33
if a>50 :
    print("Greater than 50")
elif(a>40):
    print("Greater than 40")
elif(a>30):
    print("Greater than 30")
else:
    print("Done")
# Out:
# Greater than 30

# %%
age = 25
if age<18:
    print("Minot")
elif age<65:
    print("Adult")
else:
    print("Senior Citizen")
# Out:
# Adult

# %%
import pandas as pd
data = {'name': ['Alice', 'Bob', 'Charle'], 'score':[85, 40, 75]}
df = pd.DataFrame(data)

df['Result'] = df ['score'].apply(lambda x: 'Pass' if x>50 else 'fail' )
print(df)
# Out:
#      name  score Result
# 0   Alice     85   Pass
# 1     Bob     40   fail
# 2  Charle     75   Pass

# %%
def avg(a, b):
    return a + b

# %%
avg(6,4)
# Out:
# 10

# %%
def avg(a, b=10):
    return (a + b)/2

# %%
avg(4,6)
# Out:
# 5.0

# %%
avg(4)
# Out:
# 7.0

# %%
def greet():
    print("Good Morning")

# %%
greet()
# Out:
# Good Morning

# %%
None
